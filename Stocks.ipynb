# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas_datareader as web
import dateutil.relativedelta as relativedelta
import statsmodels.api as sm
import imageio

# %matplotlib inline
plt.style.use("default")

# %%
data_path = r".\Data\Stocks"

# %%
dja = pd.read_csv(data_path + "\\" + "DJA.csv", parse_dates = True, index_col = "Date")
djua = pd.read_csv(data_path + "\\" + "DJUA.csv", parse_dates = True, index_col = "Date")

# %%
dja_log_ret = np.log(dja).diff()
# Out:
#                 DJIA
# Date
# 1885-02-16       NaN
# 1885-02-17  0.013385
# 1885-02-18  0.004401
# 1885-02-19  0.006421
# 1885-02-20 -0.007933

# %%
print(sm.qqplot(dja_log_ret['DJIA'][:].values))
# Out:
# Figure(640x480)

# %%
file.canvas.draw()

# %%
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave('movie.gif', images)

# %%
imageio.mimsave('movie.gif', images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-1df4ed8bf272> in <module>()
# ----> 1 imageio.mimsave('movie.gif', images)
#
# ~\Anaconda3\lib\site-packages\imageio\core\functions.py in mimwrite(uri, ims, format, **kwargs)
#     350                     raise ValueError("Image must be 2D " "(grayscale, RGB, or RGBA).")
#     351             else:
# --> 352                 raise ValueError("Image must be a numpy array.")
#     353
#     354             # Add image
#
# ValueError: Image must be a numpy array.

# %%
decadal_list = [x for x in range(1900,2020, 10)]

# %%
images = []

for i in decadal_list:
    file = sm.qqplot(dja_log_ret['DJIA'][str(i):str(i+10)][:].values, markersize = 2, label = "{} & {}".format(i, i+10))
    plt.legend()
    file.canvas.draw()       # draw the canvas, cache the renderer
    image = np.frombuffer(file.canvas.tostring_rgb(), dtype='uint8')
    image  = image.reshape(file.canvas.get_width_height()[::-1] + (3,))
    images.append(image)
    plt.show()

# %%
sns.set_style('white', {"xtick.major.size": 2, "ytick.major.size": 2})
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71","#f4cae4"]
sns.set_palette(sns.color_palette(flatui,7))

# %%
fct = forecasts['One'].shift(0)['1970':'2018-06'].to_frame()
actual = unrate['1970':'2018-06']
diff = fct.subtract(actual.values, axis = 'rows')
dates = diff.index.values
rec_chart = rec_dates['1970':]

fig, ax = plt.subplots(figsize = [12,6])
plt.title("SPF Current Quarter U3 Unemployment Forecast Minus Actual Print")
ax.plot(diff, color ='black', linewidth = 1)
ax.fill_between(dates, diff.iloc[:,0], 0, where = diff.iloc[:,0] >= 0, facecolor = 'green', interpolate=True)
ax.fill_between(dates, diff.iloc[:,0], 0, where = diff.iloc[:,0] <= 0, facecolor = 'red', interpolate=True)
for c in range(0, len(rec_chart)-1):
    if rec_chart.iloc[c,0] == 1:
        ax.axvspan(rec_chart.index[c], rec_chart.index[c+1], color = sns.xkcd_rgb['grey'], alpha = 0.5)
#for ax in axes:
#    ax.axvspan(, recs2k_end, color=sns.xkcd_rgb['grey'], alpha=0.5)
#    ax.axvspan(recs2k8_bgn, recs2k8_end,  color=sns.xkcd_rgb['grey'], alpha=0.5)

# %%
filtered = pd.DataFrame(index = pd.date_range(start = "1968-12-31", end = "2019-12-31", freq = 'Q'),
                        columns = ['One','Two','Three','Four','Five'])

# %%
for i in range(0,len(forecasts)-1):

# %%
forecasts.iloc[0,:].to_frame().columns

# %%
corr_dumper = []

for i in range(0,10000):
    ta1 = np.random.normal(0,1,18)
    ta2 = np.random.normal(0,1,18)

    corr_dumper.append(np.corrcoef(ta1,ta2)[0][1])

# %%
plt.plot(corr_dumper)
